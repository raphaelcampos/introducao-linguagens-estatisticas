# %% [markdown]
# # Transformações

# %%
df = read.csv("../dados/iris-dataset.csv", header=FALSE)
colnames(df) = c("sepal_length", "sepal_width", "petal_length", "sepal_width", "species")

head(df[,c('sepal_width', 'sepal_length')])
# Out:
#   sepal_width sepal_length
# 1 3.5         5.1
# 2 3.0         4.9
# 3 3.2         4.7
# 4 3.1         4.6
# 5 3.6         5.0
# 6 3.9         5.4

# %%
# eixo 1 a função recebe linha a linha
# vamos então transformar as colunas numéricas
# deixando seus valores numa escala entre 0 e 1
apply(df[,c('sepal_width', 'sepal_length')], 
      1, function(linha) {mean(linha)})
# Out:
#   [1] 4.30 3.95 3.95 3.85 4.30 4.65 4.00 4.20 3.65 4.00 4.55 4.10 3.90 3.65 4.90
#  [16] 5.05 4.65 4.30 4.75 4.45 4.40 4.40 4.10 4.20 4.10 4.00 4.20 4.35 4.30 3.95
#  [31] 3.95 4.40 4.65 4.85 4.00 4.10 4.50 4.00 3.70 4.25 4.25 3.40 3.80 4.25 4.45
#  [46] 3.90 4.45 3.90 4.50 4.15 5.10 4.80 5.00 3.90 4.65 4.25 4.80 3.65 4.75 3.95
#  [61] 3.50 4.45 4.10 4.50 4.25 4.90 4.30 4.25 4.20 4.05 4.55 4.45 4.40 4.45 4.65
#  [76] 4.80 4.80 4.85 4.45 4.15 3.95 3.95 4.25 4.35 4.20 4.70 4.90 4.30 4.30 4.00
#  [91] 4.05 4.55 4.20 3.65 4.15 4.35 4.30 4.55 3.80 4.25 4.80 4.25 5.05 4.60 4.75
# [106] 5.30 3.70 5.10 4.60 5.40 4.85 4.55 4.90 4.10 4.30 4.80 4.75 5.75 5.15 4.10
# [121] 5.05 4.20 5.25 4.50 5.00 5.20 4.50 4.55 4.60 5.10 5.10 5.85 4.60 4.55 4.35
# [136] 5.35 4.85 4.75 4.50 5.00 4.90 5.00 4.25 5.00 5.00 4.85 4.40 4.75 4.80 4.45

# %%
# eixo 2 a função recebe coluna a coluna
# vamos então transformar as colunas numéricas
# deixando seus valores numa escala entre 0 e 1
apply(df[,c('sepal_width', 'sepal_length')], 
      2, function(coluna) {mean(coluna)})
# Out:
#  sepal_width sepal_length
#     3.054000     5.843333

# %%
# eixo 1 a função recebe linha a linha
# vamos então transformar as colunas numéricas
# deixando seus valores numa escala entre 0 e 1
apply(df[,c('sepal_width', 'sepal_length')], 
      1, function(x) {x / max(x)})
# Out:
#              [,1]      [,2]      [,3]      [,4]     [,5] [,6]      [,7]
# sepal_width  0.6862745 0.6122449 0.6808511 0.673913 0.72 0.7222222 0.7391304
# sepal_length 1.0000000 1.0000000 1.0000000 1.000000 1.00 1.0000000 1.0000000
#              [,8] [,9]      [,10]     [,11] [,12]     [,13]     [,14]
# sepal_width  0.68 0.6590909 0.6326531 ⋯     0.4626866 0.4492754 0.4655172
# sepal_length 1.00 1.0000000 1.0000000 ⋯     1.0000000 1.0000000 1.0000000
#              [,15]     [,16]     [,17]     [,18]     [,19]     [,20]
# sepal_width  0.4705882 0.4925373 0.4477612 0.3968254 0.4615385 0.5483871
# sepal_length 1.0000000 1.0000000 1.0000000 1.0000000 1.0000000 1.0000000
#              [,21]
# sepal_width  0.5084746
# sepal_length 1.0000000

# %%
# eixo 2 a função recebe uma coluna inteira
# vamos então transformar as colunas numéricas
# deixando seus valores numa escala entre 0 e 1
apply(df[,c('sepal_width', 'sepal_length')], 
      2, function(x) {x / max(x)})
# Out:
#       sepal_width sepal_length
#  [1,] 0.7954545   0.6455696
#  [2,] 0.6818182   0.6202532
#  [3,] 0.7272727   0.5949367
#  [4,] 0.7045455   0.5822785
#  [5,] 0.8181818   0.6329114
#  [6,] 0.8863636   0.6835443
#  [7,] 0.7727273   0.5822785
#  [8,] 0.7727273   0.6329114
#  [9,] 0.6590909   0.5569620
# [10,] 0.7045455   0.6202532
# [11,] 0.8409091   0.6835443
# [12,] 0.7727273   0.6075949
# [13,] 0.6818182   0.6075949
# [14,] 0.6818182   0.5443038
# [15,] 0.9090909   0.7341772
# [16,] 1.0000000   0.7215190
# [17,] 0.8863636   0.6835443
# [18,] 0.7954545   0.6455696
# [19,] 0.8636364   0.7215190
# [20,] 0.8636364   0.6455696
# [21,] 0.7727273   0.6835443
# [22,] 0.8409091   0.6455696
# [23,] 0.8181818   0.5822785
# [24,] 0.7500000   0.6455696
# [25,] 0.7727273   0.6075949
# [26,] 0.6818182   0.6329114
# [27,] 0.7727273   0.6329114
# [28,] 0.7954545   0.6582278
# [29,] 0.7727273   0.6582278
# [30,] 0.7272727   0.5949367
# [31,] ⋮           ⋮
# [32,] 0.7272727   0.8734177
# [33,] 0.6363636   0.7088608
# [34,] 0.6363636   0.9746835
# [35,] 0.6136364   0.7974684
# [36,] 0.7500000   0.8481013
# [37,] 0.7272727   0.9113924
# [38,] 0.6363636   0.7848101
# [39,] 0.6818182   0.7721519
# [40,] 0.6363636   0.8101266
# [41,] 0.6818182   0.9113924
# [42,] 0.6363636   0.9367089
# [43,] 0.8636364   1.0000000
# [44,] 0.6363636   0.8101266
# [45,] 0.6363636   0.7974684
# [46,] 0.5909091   0.7721519
# [47,] 0.6818182   0.9746835
# [48,] 0.7727273   0.7974684
# [49,] 0.7045455   0.8101266
# [50,] 0.6818182   0.7594937
# [51,] 0.7045455   0.8734177
# [52,] 0.7045455   0.8481013
# [53,] 0.7045455   0.8734177
# [54,] 0.6136364   0.7341772
# [55,] 0.7272727   0.8607595
# [56,] 0.7500000   0.8481013
# [57,] 0.6818182   0.8481013
# [58,] 0.5681818   0.7974684
# [59,] 0.6818182   0.8227848
# [60,] 0.7727273   0.7848101
# [61,] 0.6818182   0.7468354
